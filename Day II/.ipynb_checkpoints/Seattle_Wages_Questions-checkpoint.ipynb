# %% [markdown]
# # Imports / Dependencies

# %% [markdown]
# ##### Import any dependencies -- Python libraries

# %%
import pandas as pd

# %% [markdown]
# ##### Read in the dataset, and assign it to a variable

# %%
wages = pd.read_csv('Seattle_Wages_Data.csv')

# %% [markdown]
# # Get a sense of the data

# %% [markdown]
# ##### How many rows and columns are in the dataset? -- Hint : Use the shape attribute

# %%
wages.shape
# Out:
# (12346, 5)

# %% [markdown]
# ##### Get the first five rows of the dataset -- Hint : Use the head() method

# %%
wages.head()
# Out:
#          Department     Last Name First Name             Job Title  \
# 0  Arts and Culture  Boas-Du Pree     Sandra      Admin Staff Asst
# 1  Arts and Culture       Bolisay     Ronald  Publc Relations Spec
# 2  Arts and Culture          Chai      Grace  Cooperative Intern *
# 3  Arts and Culture      Childers   Calandra    StratAdvsr3,Exempt
# 4  Arts and Culture        Crooks   Jennifer        Arts Prgm Spec
#
#    Hourly Rate
# 0         34.48
# 1         29.09
# 2         16.12
# 3         48.71
# 4         35.93

# %% [markdown]
# ##### Get the last five rows of the dataset -- Hint : Use the tail() method

# %%
wages.tail()
# Out:
#                      Department  Last Name First Name  \
# 12341  Seattle Public Utilities  Zemmerman      Ahanu
# 12342  Seattle Public Utilities   Zoellmer       Adam
# 12343  Seattle Public Utilities    Zollman      Karen
# 12344  Seattle Public Utilities   Zurowski      Allan
# 12345  Seattle Public Utilities      Zuver       Glen
#
#                       Job Title  Hourly Rate
# 12341             Maint Laborer         25.39
# 12342          Trng&Ed Coord,Sr         37.94
# 12343      Civil Engrng Spec,Sr         48.84
# 12344                 Carpenter         32.88
# 12345  Constr&Maint Equip Op,Sr         34.75

# %% [markdown]
# ##### Get the dataset's column names and datatypes -- Hint : Use the info() method

# %%
wages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12346 entries, 0 to 12345
# Data columns (total 5 columns):
# Department      12346 non-null object
# Last Name       12346 non-null object
# First Name      12346 non-null object
# Job Title       12346 non-null object
# Hourly Rate     12346 non-null float64
# dtypes: float64(1), object(4)
# memory usage: 482.3+ KB

# %% [markdown]
# ##### Get summary statistics of the dataset -- Hint : Use the describe() method

# %%
wages.describe()
# Out:
#        Hourly Rate
# count  12346.000000
# mean      38.974306
# std       13.724498
# min        5.110000
# 25%       28.830000
# 50%       38.850000
# 75%       48.430000
# max      166.910000

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ##### Sort the dataset (from the highest wages to lowest) -- Hint : Use the sort_values() method

# %%
wages.sort_values(by= 'Hourly Rate ', ascending=False)
# Out:
#                            Department       Last Name   First Name  \
# 1879                       City Light            Weis        Larry
# 11455        Seattle Public Utilities            Hara         Mami
# 7486                Police Department          OToole     Kathleen
# 199                        City Light           Baggs        James
# 959                        City Light           Jones      Michael
# 101    City Employees Retirement Syst      Malinowski        Jason
# 1960                       City Light       Ziemianek      Bernard
# 3554                  Fire Department        Scoggins       Harold
# 103    City Employees Retirement Syst         Nakatsu      Kenneth
# 824                        City Light          Haynes      Michael
# 1312                       City Light          Morter        Wayne
# 2871                  Fire Department         Cordova      Charles
# 3058                  Fire Department           Hagen       Jerome
# 3661                  Fire Department         Vickery         Alan
# 2990                  Fire Department     Fitzpatrick        Helen
# 6244                Police Department            Best       Carmen
# 7261                Police Department           Maxey        Brian
# 91     City Employees Retirement Syst           Davis      Jeffrey
# 941                        City Light         Johnson      DaVonna
# 7842                Police Department         Tarrant        Perry
# 7313                Police Department          Merner       Robert
# 6449                Police Department         Cordner        Janet
# 8010                Police Department          Wilske       Steven
# 1066                       City Light       Laschober        Paula
# 4572                 Parks Department         Aguirre        Jesus
# 609                        City Light         Enright        Kelly
# 4338                   Mayor's Office          Murray       Edward
# 2464       Dept of Finance & Admn Svc         Podesta         Fred
# 9791   Seattle Dept of Transportation           Kubly        Scott
# 1798                       City Light            Tran         Tuan
# ...                               ...             ...          ...
# 3880                   Human Services            Farr        Leija
# 3893                   Human Services          Galato        Rahel
# 6022                 Parks Department          Wilson       Joshua
# 4946                 Parks Department             Eng  Christopher
# 3895                   Human Services  Garcia-Rosario    Sajuarita
# 4851                 Parks Department           Craig  Christopher
# 3997                   Human Services         Matewos        Nahom
# 3849                   Human Services           Davis      Symmone
# 4880                 Parks Department           Davis      Russell
# 3819                   Human Services    Cano-Alvarez       Camila
# 3824                   Human Services        Chambers       Trevon
# 3834                   Human Services          Coaxum      Tykayla
# 3837                   Human Services         Collins     Saundrea
# 3842                   Human Services     Cruz-Chavez       Yadira
# 6036                 Parks Department        Woodruff     Woodford
# 3847                   Human Services         Darmmeh        Arbie
# 3854                   Human Services          Diallo        Adama
# 5248                 Parks Department         Johnson     Jonathan
# 4894                 Parks Department         Derrick       Tammie
# 1971        Civil Service Commissions     Halliburton    Christian
# 1967        Civil Service Commissions       Bonfrisco          Amy
# 1974        Civil Service Commissions   Pailca-Larson       Sandra
# 1968        Civil Service Commissions           Davis    Angelique
# 1969        Civil Service Commissions   de los Santos         Eric
# 1973        Civil Service Commissions            Nark         Joel
# 4258         Legislative-City Council           Marks       Alfred
# 4254         Legislative-City Council        Levytsky         John
# 4225         Legislative-City Council          Felder       Donald
# 4236         Legislative-City Council            Hawe      William
# 4238         Legislative-City Council         Holohan    Elizabeth
#
#                         Job Title  Hourly Rate
# 1879   City Light General Mgr&CEO        166.91
# 11455         SPU General Mgr&CEO        134.10
# 7486         Seattle Police Chief        127.68
# 199     Electric Util Exec 3,Ofcr        116.54
# 959     Electric Util Exec 3,Ofcr        111.24
# 101                    Executive4        109.74
# 1960     Electric Util Exec 3,Dir        109.58
# 3554                   Executive4        107.84
# 103                  Executive4 *        107.07
# 824          Electric Util Exec 2        105.00
# 1312     Electric Util Exec 3,Dir        103.38
# 2871                   Executive4        102.08
# 3058                   Executive4        102.08
# 3661                   Executive4        102.08
# 2990                   Executive4        102.07
# 6244                   Executive4         99.55
# 7261                   Executive4         99.55
# 91                     Executive4         98.66
# 941      Electric Util Exec 3,Dir         96.97
# 7842                   Executive4         96.66
# 7313                   Executive4         96.66
# 6449                   Executive4         96.66
# 8010                   Executive4         96.66
# 1066    Electric Util Exec 3,Ofcr         95.79
# 4572                   Executive4         95.14
# 609      Electric Util Exec 3,Dir         93.88
# 4338                        Mayor         93.48
# 2464                   Executive4         93.15
# 9791                   Executive4         91.94
# 1798     Electric Util Exec 3,Dir         91.21
# ...                           ...           ...
# 3880   Yth Emplmnt Enrollee-Sum *         15.00
# 3893   Yth Emplmnt Enrollee-Sum *         15.00
# 6022         Work Trng Enrollee *         15.00
# 4946         Work Trng Enrollee *         15.00
# 3895   Yth Emplmnt Enrollee-Sum *         15.00
# 4851         Work Trng Enrollee *         15.00
# 3997   Yth Emplmnt Enrollee-Sum *         15.00
# 3849   Yth Emplmnt Enrollee-Sum *         15.00
# 4880         Work Trng Enrollee *         15.00
# 3819   Yth Emplmnt Enrollee-Sum *         15.00
# 3824   Yth Emplmnt Enrollee-Sum *         15.00
# 3834   Yth Emplmnt Enrollee-Sum *         15.00
# 3837   Yth Emplmnt Enrollee-Sum *         15.00
# 3842   Yth Emplmnt Enrollee-Sum *         15.00
# 6036         Work Trng Enrollee *         15.00
# 3847   Yth Emplmnt Enrollee-Sum *         15.00
# 3854   Yth Emplmnt Enrollee-Sum *         15.00
# 5248         Work Trng Enrollee *         15.00
# 4894         Work Trng Enrollee *         15.00
# 1971       Civil Svc Commissioner          5.53
# 1967       Civil Svc Commissioner          5.53
# 1974       Civil Svc Commissioner          5.53
# 1968       Civil Svc Commissioner          5.53
# 1969       Civil Svc Commissioner          5.53
# 1973       Civil Svc Commissioner          5.53
# 4258      OPA Review Board Member          5.11
# 4254      OPA Review Board Member          5.11
# 4225      OPA Review Board Member          5.11
# 4236      OPA Review Board Member          5.11
# 4238      OPA Review Board Member          5.11
#
# [12346 rows x 5 columns]

# %% [markdown]
# # Querying the data

# %% [markdown]
# ##### How many jobs are there in the dataset? -- Hint : Use the describe() method after indexing on 'Job Title'

# %%
wages['Job Title'].describe()
# Out:
# count              12346
# unique              1026
# top       Pol Ofcr-Patrl
# freq                 498
# Name: Job Title, dtype: object

# %% [markdown]
# ##### What is the highest salary? Save that output to a variable -- 'wage_max'. -- Hint : Use the max() method

# %%
wage_max = wages['Hourly Rate '].max()

# %% [markdown]
# ##### Who is the highest earning individual in the dataset? -- Hint : Use boolean indexing for the max 'Hourly Rate ' value

# %%
wages[wages['Hourly Rate '] == wage_max]
# Out:
#       Department Last Name First Name                   Job Title  \
# 1879  City Light      Weis      Larry  City Light General Mgr&CEO
#
#       Hourly Rate
# 1879        166.91

# %% [markdown]
# ##### How many people work at the highest earning indivdiual's department? -- Hint : Use the count() method

# %%
wages[wages['Department'] == 'City Light'].count()
# Out:
# Department      1850
# Last Name       1850
# First Name      1850
# Job Title       1850
# Hourly Rate     1850
# dtype: int64

# %% [markdown]
# ##### What is the lowest salary? Save that output to a variable -- 'wage_low'. -- Hint : Use the min() method

# %%
wage_min = wages['Hourly Rate '].min()

# %% [markdown]
# ##### Who is the lowest earning individual in the dataset? -- Hint : Use boolean indexing for the min 'Hourly Rate ' value

# %%
wages[wages['Hourly Rate '] == wage_min]
# Out:
#                     Department Last Name First Name                Job Title  \
# 4225  Legislative-City Council    Felder     Donald  OPA Review Board Member
# 4236  Legislative-City Council      Hawe    William  OPA Review Board Member
# 4238  Legislative-City Council   Holohan  Elizabeth  OPA Review Board Member
# 4254  Legislative-City Council  Levytsky       John  OPA Review Board Member
# 4258  Legislative-City Council     Marks     Alfred  OPA Review Board Member
#
#       Hourly Rate
# 4225          5.11
# 4236          5.11
# 4238          5.11
# 4254          5.11
# 4258          5.11

# %% [markdown]
# ##### How many people work at the lowest earning indivdiual's department? -- Hint: Use the count() method

# %%
wages[wages['Department'] == 'Legislative-City Council'].count()
# Out:
# Department      106
# Last Name       106
# First Name      106
# Job Title       106
# Hourly Rate     106
# dtype: int64

# %% [markdown]
# ##### What is the difference between the highest earning and lowest earning individuals?

# %%
wage_max-wage_min
# Out:
# 161.79999999999998

# %% [markdown]
# # Stop Point!

# %%
#cool
